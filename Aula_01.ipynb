# %% [markdown]
# <a href="https://colab.research.google.com/github/Melque84/Estudo/blob/main/Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print(a)

# %% [markdown]
# Aula 01

# %%
a=5
b=9
print(f'O valor de "a" é {a} e o valor da variavel "b" é {b}.')
# Out:
# O valor de "a" é 5 e o valor da variavel "b" é 9.

# %%
a,b=5, 9
print(f'O valor de "a" é {a} e o valor de "b é {b}.')
# Out:
# O valor de "a" é 5 e o valor de "b é 9.

# %%
Celular=1990
Carregador=118.50
Total=Celular+Carregador
print(f'O valortotal foi de R${Total:.2f}.')
# Out:
# O valortotal foi de R$2108.50.

# %%
a='Melque'
b='Darana'
print(f'O pai é {a} e a mãe é {b}.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1150/1373344027.py in <cell line: 0>()
# ----> 1 a=Melque
#       2 b=Darana
#       3 print(f'O pai é {a} e a mãe é {b}.')
#
# NameError: name 'Melque' is not defined

# %%
a='melque'
b='Darana'
print(f'O pai é {a} e a mãe é {b}.')
# Out:
# O pai é melque e a mãe é Darana.

# %%
a=41
b='filho da Maria'
c='a filha da Leia'
d=36
print(f'O {b} tem {a} anos e {c} tem {d} anos.')
# Out:
# O filho da Maria tem 41 anos e a a filha da Leia tem 36 anos.

# %%
a='melque'
b='darana'
c='vitoria'
print(f'O resultado do {a} + {b} é a {c}.')
# Out:
# O resultado do melque + darana é a vitoria.

# %%
Diametro=84.728
a=-0.054
b=0.077
Diametrominimo=Diametro+a
Diametromaximo=Diametro+b
print(f' Diametro minimo é {Diametrominimo:.2f}.')
print(f' Diametro maximo é {Diametromaximo:.2f}.')
# Out:
#  Diametro minimo é 84.67.
#  Diametro maximo é 84.80.

# %%
Herança=120
Herdeiros=3
Resultado=Herança/Herdeiros
print(f'cada herdeiro recerbeu {Resultado} vindo da mãe.')
# Out:
# cada herdeiro recerbeu 40.0 vindo da mãe.

# %%
Consulta=240
IRPF=Consulta*27.5/100*80
Quantidade_de_consulta=80

print(f'O dentista paga de imposto R$ {IRPF} por mês.')
# Out:
# O dentista paga de imposto R$ 5280.0 por mês.

# %%
Boleto=867.23
meses=3
Boleto_final=901.14
Taxa=((901.14-867.23)/3/867.23)*100
print(f'a taxa corresponde a {Taxa}% ao mês.')
# Out:
# a taxa corresponde a 1.3033835699103262% ao mês.

# %%
c=867.23
m=901.14
n=3
Taxa=((m-c)/n/c)*100
print(f' Ataxa corresponde a {Taxa:.2f}% ao mês.')
# Out:
#  Ataxa corresponde a 1.30% ao mês.

# %%
VP=120
i=10/100
n=3
VF=VP*(1+i)**3
print(f' o valor da empresa daqui a {n} anos será de R${VF:.2f}.')
# Out:
#  o valor da empresa daqui a 3 anos será de R$159.72.

# %%
VP=566
M=614.30
n=6
i=((M/VP)**(1/n)-1)*100
print(f'A taxa corresponde a {i:.2f}% ao mês.')
# Out:
# A taxa corresponde a 1.37% ao mês.

# %%
Celular=1990
Carregador=118.50
Total=Celular+Carregador
print(f'O custo do aparelho é R${Total:2f}.')
# Out:
# O custo do aparelho é R$2108.500000.

# %%
Diametro=84.728
a=-0.054
b=0.077
diametrominimo=Diametro+a
diametromaximo=Diametro+b
print(f'O diametro máximo é {diametromaximo:.2f} e o diametro mínimo é {diametrominimo:.2f}.')
# Out:
# O diametro máximo é 84.80 e o diametro mínimo é 84.67.

# %%
Herança=120
herdeiros=3
Partes=Herança/herdeiros
print(f'Cada herdeiros recebeu R${Partes} vindo da mãe.')
# Out:
# Cada herdeiros recebeu R$40.0 vindo da mãe.

# %%
Consulta=240
Imposto=27.5
quantidade_de_consultas=80
IRPF=Consulta*Imposto/100*quantidade_de_consultas
print(f'O valor pago pelo dendista é de R${IRPF} por mês.')
# Out:
# O valor pago pelo dendista é de R$5280.0 por mês.

# %%
VP=867.23
tempo=3
VF=901.14
taxa=((VF-VP)/3/VP)*100
print(f'A taxa corresponde a {taxa:.2f}% ao mês.')
# Out:
# A taxa corresponde a 1.30% ao mês.

# %%
VP=120
taxa=10
tempo=3
VF=VP*(1+10)**3
#Fórmula=Valor_presente_multiplicado_pela_constante_mas_a_taxa_elevado_ao_tempo
print(f'O valor da empresa dqui a 3 anos será de R${VF:.2f}.')
# Out:
# O valor da empresa dqui a 3 anos será de R$159720.00.

# %%
#Radiciação usa a fórmula ((m/c)**(1/n)*100)
VP=566
tempo=6
VF=614.30
Taxa=((VF/VP)**(1/tempo)-1)*100
print(f'A taxa corresponde a {Taxa:.2f}% ao mes.')
# Out:
# A taxa corresponde a 1.37% ao mes.

# %%
a='Melque'
b='Darana'
c='Vitoria'
print(f'O {a} e casado com a {b} que é pai da {c}.')
# Out:
# O Melque e casado com a Darana que é pai da Vitoria.

# %% [markdown]
# # Ecercicios da aula 1

# %%
Valor_da_mercdoria=248.77
valor_do_frete=14.48
Valor_total=Valor_da_mercdoria+valor_do_frete
print(f'O custo total foi de R${Valor_total:.2f}')
# Out:
# O custo total foi de R$263.25

# %%
Vale_presente=600
Compra_1=240
Compra_2=185
Saldo=Vale_presente-Compra_1-Compra_2
print(f'O saldo do cartão é R${Saldo:.3f}.')
# Out:
# O saldo do cartão é R$175.000.

# %%
Suportes=45.50
Tábua=78
Parafuso=0.50
Total=(45.50)*3+(78)*2+(0.50)*6
print(f'O custo total da prateleira é de R${Total:.2f}')
# Out:
# O custo total da prateleira é de R$295.50

# %%
Comprimento=2
Comprimentominimo=Comprimento-0.2
Comprimentomaximo=Comprimento+0.2
print(f'Ocomprimento minimo é {Comprimentominimo}')
print(f'O comprimento maximo é {Comprimentomaximo}')
# Out:
# Ocomprimento minimo é 1.8
# O comprimento maximo é 2.2

# %% [markdown]
# # M=c(1+i*n)
# M= Monante
# C= Capital
# I= Taxa
# N= Tempo
# 1= já vem na fórmula.
#
# **JUROS SIMPLES**

# %%
Dívida=12000.00
Tempo=12
Taxa=1/100
VF=Dívida*(1+Taxa*Tempo)
print(f' O valor a ser pago é R${VF:.2f}.')
# Out:
#  O valor a ser pago é R$13440.00.

# %% [markdown]
# # M=C(1+I)**n      POTENCIAÇÃO
#
#
# M= Montante
# C= Cápital
# i= Taxa
# N= Tempo
# 1=  já vem na fórmula
#
# **JUROS COMPOSTODS**

# %%
Dívida=12000.00
Tempo=12
taxa=1/100
VF=12000.00*(1+1/100)**12
print(f'O valor a ser pago é R${VF:.2f}')
# Out:
# O valor a ser pago é R$13521.90

# %%
# DIVISÃO DE JUROS COMPOSTOS

C=1440.00
M=1610.12
N=12
TAXA=((M/C)**(1/N)-1)*100
print(f'A TAXA É{TAXA:.2F}% AO MES.')
# Out:
# A TAXA É0.93% AO MES.

# %%
# JUROS COMPOSTOS
c=2500.00
m=14840.07
n=12
taxa=((m/c)**(1/12)-1)*100
print(f' A taxa é de {taxa:.2f}% ao mes')
# Out:
#  A taxa é de 16.00% ao mes

# %%
Capital=1000
Tempo=120
Taxa=0.5/100
VF=Capital*(1+Taxa)**Tempo
print(f'o montante a receber é R${VF:.2f}')
# Out:
# o montante a receber é R$1819.40

# %%
Cápital=1200.00
Tempo=12
VF=1320.90
taxa=((VF-Cápital)/(Cápital*12))*100
print(f'taxa é {taxa:.2f}')
# Out:
# taxa é 0.84

# %% [markdown]
# # **Fatorações e expansão de expreções**
#   x² + 8x

# %%
from sympy import *
x , y =symbols ('x y')
factor (x**2 + 8*x)
y= factor (x**2 + 8*x)
print(y)
# Out:
# x*(x + 8)

# %% [markdown]
# Forma fatorad xy³+2x²y4

# %%
from sympy import *
x, y = symbols ('x y')
factor (x * y**3 + 2* x**2*y**4)
res = factor (x * y**3 + 2* x**2*y**4)
print(res)
# Out:
# x*y**3*(2*x*y + 1)

# %% [markdown]
# forma fatorada
# x²-5x+6 / x-2

# %%
from sympy import *
x , y = symbols ('x y ')
factor ((x**2-5*x+6) / (x - 2))
y = factor ((x**2-5*x+6) / (x - 2))
print(y)
# Out:
# x - 3

# %% [markdown]
# # **Expanção de expreções**
# x(x + y)

# %%
from sympy import *
x , y = symbols ('x y')
expand (x*(x + 8))
res = expand (x* (x + 8))
print(res)
# Out:
# x**2 + 8*x

# %% [markdown]
# Expanção com produtos notáveis.
# (x+y) elevado 4

# %%
from sympy import *
x , y = symbols ('x y')
expand ((x +y) **4)
y = expand ((x + y) **4)
print (y)
# Out:
# x**4 + 4*x**3*y + 6*x**2*y**2 + 4*x*y**3 + y**4

# %% [markdown]
# # **GRÀFICOS**
# y = x³ + 2x - 1

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace (-5,5,100)
y = x**3 + 2*x - 1
plt.plot (x,y)
plt.show ()

# %% [markdown]
# Uma empresa que fabrica antenas de TV digital vende cada unidade por R$186,00. O custo para produção de cada unidade é de R$109,00 e os custos fixo total no mês corresponde a R$11.200,00.
# Escreva a função receita e a função custos.
# Faça u gráfico dessa dua funções em um mesmo sistema de eixos coordenados.

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.linspace (0,300,100)
y1 = 186 * x1
y2 = 109 *x1 + 11200
plt.plot (x1 , y1)
plt.plot (x1 , y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# A receita de uma empresa é dada por R(x) = 419 x
# e os custo por C(x) = 271 + 15000 onde x é a quantidade comercializada de um determinado produto. Faça, em um mesmo sistema de eixo o gráfico de cada uma das funções?

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.linspace (0, 200, 100)
y1 = 419*x1
y2 = 271*x1 + 15000
plt.plot (x1 , y1)
plt.plot (x1 , y2)
plt.show()

# %% [markdown]
# # **Exercício**
# Considere a função F(x) = 2x² + 19x - 15
# Calculu F (2)?

# %%
from sympy import *
x , y =symbols ('x y')
y = 2*x**2 + 19*x - 25
res = y . subs (x,2)
print (f'Oresultado é: {res:.2f}')
# Out:
# Oresultado é: 21.00

# %% [markdown]
# O lucro mensal "L" é dado em função do preço da venda "x" de u,a determinada mercadoria por meio da expressão L(x) = -400x² + 12000x ......Calcule o lucro mensal quando o preço de venda dessa mercadoria é R$ 10,00.

# %%
from sympy import *
x,y = symbols ('x y')
Y = -400*x**2 + 12000*x
res = Y.subs (x,10)
print (f' O lucro mensal é R$ {res:.2f}')
# Out:
#  O lucro mensal é R$ 80000.00

# %% [markdown]
# Dadas as funções F(x)= 7x+1  e  G(x)= 14x-2,  Obtenha a função compsta F(g(x))?

# %%
from sympy import *
f,g,x, = symbols ('f g x')
f= 7*x+1
g= 14*x-2
f.subs (x,g)
# Out:
# 98*x - 13

# %% [markdown]
# Aula 2    Calculando RAIZ
# F(x) = 12x³-100x²-30x+2.

# %%
import numpy as np
c = [12, -100, -30, 2]
np.roots(c)
# Out:
# array([ 8.62107781, -0.34395143,  0.05620696])

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.linspace (-2, 9, 100)
y1 = 419*x1
y2 = 271*x1 + 15000
plt.plot (x1 , y1)
plt.plot (x1 , y2)
plt.grid()
plt.show()

# %%
from sympy import *
x , y = symbols ('x y')
y = -7*x**2 + 5200*x-80000
resultado = y.subs (x, 350.00)
print (f'o resultado é: {resultado:.2f}')
# Out:
# o resultado é: 882500.00

# %%
matpri = 27936.1
frete = 1243.90
custo = matpri + frete
print (f'o custo total foi: {custo:.2f}.')
# Out:
# o custo total foi: 29180.00.

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace (0,10,100)
px = ('x px')
y=-80*x**2+7900*x-5000
plt.plot (x,y)
plt.plot (x,px)
plt.show ()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_895/2285582497.py in <cell line: 0>()
#       5 y=-80*x**2+7900*x-5000
#       6 plt.plot (x,y)
# ----> 7 plt.plot (x,px)
#       8 plt.show ()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# ...

# %%
from sympy import *
x,y = symbols ('x y')
Y = -80*x**2+7900*x-5000
res = Y.subs (x,0)
print (f' O lucro mensal é R$ {res:.2f}')
# Out:
#  O lucro mensal é R$ -5000.00

# %%
c = 566.00
m = 614.30
n = 6
taxa=((m-c)/(c*n)+1)*100
print(f'A taxa de juso foi R${taxa:.2f}% ao mês.')
# Out:
# A taxa de juso foi R$101.42% ao mês.

# %%
c=566.00
m=614.30
n=6
Taxa=((m-c)/n/c)*100
print(f' Ataxa corresponde a {Taxa:.2f}% ao mês.')
# Out:
#  Ataxa corresponde a 1.42% ao mês.

# %%
from sympy import *
x , y = symbols('x y')
factor(x**2*y**5+3*x**3*y**4-x**3*y**6)
# Out:
# -x**2*y**4*(x*y**2 - 3*x - y)

# %%
diametro=80
a=-0.102
b=0.222
diametrominimo= diametro + a
diametromaximo= diametro + b
print(f'diametro minimo {diametrominimo:.3f}')
print(f' diametro maximo {diametromaximo:.3f}')
# Out:
# diametro minimo 79.898
#  diametro maximo 80.222

# %%
from sympy import *
x=symbols ('x')
expanded_expression = expand((12*x**5-3*x**4+4*x**2)**2)
print(expanded_expression)
# Out:
# 144*x**10 - 72*x**9 + 9*x**8 + 96*x**7 - 24*x**6 + 16*x**4

# %%
from sympy import *
x,y = symbols ('x y')
Y =2*x**2+7*x+9000
res = Y.subs (x,30)
print (f' O lucro mensal é R$ {res:}')
# Out:
#  O lucro mensal é R$ 11010

# %%
import matplotlib.pyplot as plt
import numpy as np
x= np.linspace (0,10,100)
r=193.57*x
c=129*x+18322.80
plt.plot (x,r)
plt.plot (x,c)
plt.show ()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace (0,10,100)
y = -0.008*x**2 + 0.8*x
plt.plot (x,y)
plt.show ()

# %%
from sympy import *
x,r, c=symbols('x r c')
# Out:
# O resultdo é:800.00

# %%
from sympy import *
x , y = symbols ('x y ')
factor (x**2*y**5+3*x**3*y**4-x**3*y**6)
# Out:
# -x**2*y**4*(x*y**2 - 3*x - y)

# %%
import numpy as np
c= [2, 10, -4]
np.roots(c)
# Out:
# array([-5.37228132,  0.37228132])

# %%
from sympy import *
x,y=symbols('x y')
res=expand((2*x+y)**3)
print(res)
# Out:
# 8*x**3 + 12*x**2*y + 6*x*y**2 + y**3

# %%
from sympy import *
x,y = symbols ('x y')
y = -7*x**2+5200*x-80000
res = y.subs (x,350)
print(f'o resultado é: {res:.2f}')
# Out:
# o resultado é: 882500.00

# %% [markdown]
# **Derivada primeira.**

# %%
from sympy import *
x, f = symbols ('x f')
f= 5*x**3+4*sin(x)-exp(3*x)
diff(f, x)
# Out:
# 15*x**2 - 3*exp(3*x) + 4*cos(x)

# %% [markdown]
# **Derivada segunda**

# %%
from sympy import *
x,f= symbols ('x, f')
f=5*x**3+4*sin(x)-exp(3*x)
diff (f, x, 2)
# Out:
# 30*x - 9*exp(3*x) - 4*sin(x)

# %%
from sympy import *
x, c= symbols ('x c')
c= x**2-112*x+4500
df= diff(c, x)
d2f= diff(c, x, 2)
p= solve(Eq(df, 0))
ds= d2f.subs(x, p [0])
print(f'Produçã: {p[0]}')
print(f'Derivada segunda:{ds}')
# Out:
# Produçã: 56
# Derivada segunda:2

# %% [markdown]
# A relação entre o preço de venda "x" e o lucro "L" de uma determinada mercadoria é L(x)=-48x² + 12000x.
# Calcule o preço que máximiza o lucro e o respectivo lucro máximo? **negrito**

# %%
from sympy import *
x, l= symbols('x l')
l= -48*x**2+12000*x
df= diff(l, x)
d2f=diff(l, x, 2)
p= solve(Eq(df, 0))
ds= d2f.subs(x, p[0])
LM= l.subs(x, p[0])
print(f'Preço ótimo: R${p[0]}')
print(f'Derivaa segunda: {ds}')
print(f'Lucro máximo: R${LM}')
# Out:
# Preço ótimo: R$125
# Derivaa segunda: -96
# Lucro máximo: R$750000

# %% [markdown]
# DESRIÇÂO MUITO GRANDE.
# Consedere a função F(x,y)= 2x+y²+x².  Obtenha e classifique os respectiivos pontos criticos.

# %%
from sympy import *
x, y, f = symbols ('x y f')
f= 2*x + y**2 + x**2
fx= diff(f, x) #1º derivada em relação a x
fy= diff(f, y) #1º derivada em relação a y
fxx= diff(f, x, 2)  #2º derivada em relação x
fyy= diff(f, y, 2)  #2º derivada em relação y
fxy= diff(fx, y)   # derivada em relação a y da função fx
fyx= diff(fy, x)   #derivada em relação e x da função fy
px= solve(Eq(fx, 0))
py= solve(Eq(fy, 0))
fxxp= fxx.subs({x:px[0], y:py[0]})
fyyp= fyy.subs({x:px[0], y:py[0]})
fxyp= fxy.subs({x:px[0], y:py[0]})
fyxp= fyx.subs({x:px[0], y:py[0]})
D= fxxp*fyyp - fxyp*fyxp
print(f'Solução: P ({px[0]}, {py[0]})')
print(f'Determinante: {D}')
print(f'Derivada segunda em relação a x: {fxxp}')
# Out:
# Solução: P (-1, 0)
# Determinante: 4
# Derivada segunda em relação a x: 2

# %% [markdown]
# INTEGRAL DEFINIDA = ANTI DERIVADA
# Calcule a integral indefinida da função F(x)= 7x5 -4x² -4x +19.        conta pequena...

# %%
from sympy import *
x,f= symbols ('x f')
f= 7*x**5-4*x**2-4*x+19
integrate(f, x)
# Out:
# 7*x**6/6 - 4*x**3/3 - 2*x**2 + 19*x

# %% [markdown]
# INTEGRAL INEFINIDA
# Calcule a integral definida da função F(x)= 7x5 -4x² -4x +19.        conta pequena...

# %%
from sympy import *
x, f= symbols('x f')
f= 7*x**5-4*x**2-4*x+19
integrate(f, (x, 0, 2))
# Out:
# 94

# %% [markdown]
# Calcule a área abaixoda função f(x)= x3-x no intevalo [2, 4] e faça o respectivo gráfico.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import *
x, f= symbols ('x f')
f= x**3-x
A= integrate(f, (x, 2, 4))
x= np.linspace(1.5, 4.5, 1000)
f= x**3-x
plt.plot(x, f, color='red')
plt.axhline (color='red')
plt.fill_between (x, f, where= [(x>2) and (x<4) for x in x], color= 'blue')
plt.show()
print(f'Àrea:{A:.2f}')
# Out:
# Àrea:54.00

# %% [markdown]
# Calcule a área entre as funções f(x)= x+2 e G(x)= 3/x no intervalo [1, 5]. Faça o gráfico?

# %%
import matplotlib.pyplot as plt
from sympy import *
import numpy as np
x, f, g= symbols('x f g')
f= x+2
g= 3/x
A= integrate((f-g), (x, 1, 5))
x= np.linspace(0.5, 5.5, 1000)
f= x+2
g= 3/x
plt.plot (x, f, color='blue')
plt.plot (x, g, color='red')
plt.axhline(color='black')
plt.fill_between (x, f, g, where=[(x>1) and (x<5) for x in x], color='cyan')
plt.show()
print(f'Àrea: {A:.2f}')
# Out:
# Àrea: 15.17

# %%
import sys
# !{sys.executable}-M pip install pulp
# Out:
# /bin/bash: line 1: /usr/bin/python3-M: No such file or directory

# %%
from pulp import*
prob = LpProblem('exemplo1',LpMaximize)
x1=LpVariable("Bolas de basquete",0)
x2=LpVariable("camisetas",0)
x3=LpVariable("raquetes",0)
prob+=22*x1+17*x2+45*x3
prob+=37*x1+32*x2+112*x3<=5000
prob+=x1>=10
prob+=x2>=10
prob+=x3>=10
prob.solve()
for v in prob.variables():
  print(v.name,"=",v.varValue)
print("Lucro Máximo=",value(prob.objective))
# Out:
# Bolas_de_basquete = 96.216216
# camisetas = 10.0
# raquetes = 10.0
# Lucro Máximo= 2736.7567520000002

# %%
import sys
# !{sys.executable} -m pip install pulp

# %% [markdown]
# **2º PROVA**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
x=np.array([3, 6])
y=np.array([2000, 3000])
a, b, correlação, p, erro=stats.linregress(x, y)
print(f'reta de regressão: y={a:.2f} x + ({b:.2f})')
print(f'Coeficiente de correlação: r={correlação:.4f}')
f=a*x+b
plt.plot (x, f, 'o', label='dados originais')
plt.plot(x, f, 'r', label= 'Reta de regressao')
plt.legend()
plt.show()
# Out:
# reta de regressão: y=333.33 x + (1000.00)
# Coeficiente de correlação: r=1.0000

# %%
#derivada da função
from sympy import *
x,f= symbols('x f')
f= 19*x**6-33*x**3+111*x+19
diff(f, x)
# Out:
# 114*x**5 - 99*x**2 + 111

# %%
#maximo Lucro
from sympy import *
x, y= symbols ('x y')
y= 1340*x-0.08*x**2
dy=diff(y, x)
preco= solve(Eq(dy, 0))
print(f'preço otimo:{preco[0]}')
# Out:
# preço otimo:8375.00000000000

# %%
# Polinômio que interpola os pontos (0,2), (3,7) e (10,-2)
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import *
x= (0,3,10)
y= (2,7,-2)
f= interp1d (x, y, kind='quadratic')
xi= np.linspace (2,10, 100)
yi= f(xi)
plt.plot(x, y, 'o')
plt.plot(xi, yi)
plt.show()

# %%
from scipy.interpolate import *
x = (0,3,10)
y= (2,7,-2)
f= lagrange(x, y)
print(f)
# Out:
#          2
# -0.2952 x + 2.552 x + 2

# %%
#Previsão para próximo mês.
import numpy as np
from scipy import stats
x= np.array([3, 6])
y= np.array([2, 3])
a, b, correlação, p, erro=stats.linregress(x, y)
mes = 7
estimativa= a*mes +b
print(f'Estimativa:R${estimativa:.2f}')
# Out:
# Estimativa:R$3.33

# %%
import matplotlib.pyplot as plt
from sympy import *
import numpy as np
x_sym, f_sym = symbols('x f') # Use different names for symbolic variables

# Define the symbolic function f
f_sym = -4*x_sym**2 + 40*x_sym - 7

# Calculate the definite integral from x=0 to x=10
A = integrate(f_sym, (x_sym, 0, 10))

# For plotting, use numpy arrays
x_plot = np.linspace(-1, 11, 1000) # Extend range slightly to see full curve
f_plot = -4*x_plot**2 + 40*x_plot - 7

plt.plot(x_plot, f_plot, color='blue', label='f(x)')
plt.axhline(0, color='black') # Plot x-axis
plt.axvline(0, color='black') # Plot y-axis

# Fill the area under f(x) from x=0 to x=10
plt.fill_between(x_plot, f_plot, where=((x_plot >= 0) & (x_plot <= 0)), color='cyan', alpha=0.5)

plt.legend()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfico de f(x) e Área Integrada')
plt.grid(True)
plt.show()

print(f'Àrea: {A:.2f}')
# Out:
# Àrea: 596.67

# %%
import matplotlib.pyplot as plt
from sympy import *
import numpy as np
x, f = symbols('x f')
f= -4*x**2+40*x-7
A= integrate(f, (x, 0, 0))
x= np.linspace(-0.5, 0.5, 100)
f= -4*x**2+40*x-7
plt.plot (x, f, color='blue')
plt.axhline(color='black')
plt.fill_between (x, f, where=[(x>0) and (x<0) for x in x], color='cyan')
plt.show()
print(f'Àrea: {A:.2f}')
# Out:
# Àrea: 0.00

# %%
import matplotlib.pyplot as plt
from sympy import *
import numpy as np
x=np.array([1, 2, 3, 4, 5])
y= np.array([180, 120, 150, 190, 210])
a, b, correlação,p, erro = stats.linregress(x, y)
print (f'Reta de regressão:y {a:.2f} b +{b:.2f}')
print(f'coeficiente de correlação: 'r'{correlação:.4f}')
plt.plot(x, y, 'o', label='dados originais')
f= a*x+b
plt.plot(x, f, 'r', label = 'reta de regressão')
plt.ylim(100,240)
plt.legend()
plt.show()
# Out:
# Reta de regressão:y 13.00 b +131.00
# coeficiente de correlação: {correlação:.4f}

# %%
# integral da função
from sympy import *
x, f= symbols ('x f')
f= 5*x**2+3*x+1
integrate(f, (x, 0, 4))
# Out:
# 404/3

# %%
# Reta que interpola nos pontos(2, 5) e (7, 10)
from scipy.interpolate import *
x = [2, 7]
y = [5, 10]
f = lagrange (x , y)
print(f)
# Out:
#
# 1 x + 3

# %%
# Calcule a derivada primeira de F= 18x4 -14x2 +22x -1
from sympy import *
x, f = symbols ('x f')
f= 18*x**4-14*x**2+22*x-1
diff(f,x)
# Out:
# 72*x**3 - 28*x + 22
